# %% [markdown]
# ## Desafio 3 do [Guilherme Silveira](https://twitter.com/guilhermecaelum)
#
# Colocar o número de avaliações por filme, isto é, não só a média mas o TOTAL de votos por filme.

# %%
import pandas as pd
filmes = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/introducao-a-data-science/master/aula0/ml-latest-small/movies.csv")
avaliacoes = pd.read_csv("https://github.com/alura-cursos/introducao-a-data-science/blob/master/aula0/ml-latest-small/ratings.csv?raw=true")

# %%
filmes.columns = ["filmeId", "titulo", "generos"]
avaliacoes.columns = ["usuarioId", "filmeId", "nota", "momento"]

# %%
nota_media_por_filme = avaliacoes.groupby("filmeId")["nota"].mean()

# %%
avaliacoes_por_filme = avaliacoes.groupby("filmeId")["nota"].count()

# %%
avaliacoes_por_filme = avaliacoes_por_filme.rename("votos")

# %%
filmes_com_media = filmes.join(nota_media_por_filme, on="filmeId")

# %%
filmes_com_media = filmes_com_media.join(avaliacoes_por_filme, on="filmeId")

# %%
filmes_com_media.head(15)
# Out:
#     filmeId                              titulo  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
# 5         6                         Heat (1995)
# 6         7                      Sabrina (1995)
# 7         8                 Tom and Huck (1995)
# 8         9                 Sudden Death (1995)
# 9        10                    GoldenEye (1995)
# 10       11      American President, The (1995)
# 11       12  Dracula: Dead and Loving It (1995)
# 12       13                        Balto (1995)
# 13       14                        Nixon (1995)
# 14       15             Cutthroat Island (1995)
#
#                                         generos      nota  votos
# 0   Adventure|Animation|Children|Comedy|Fantasy  3.920930  215.0
# ...
